# %%
a = 'C,B,A'
b = ['F','G','H']
a_split=a.split(',')
combined_list=a_split+b
combined_list[0]='K'
del combined_list[2]
combined_list[1:4]=[]
combined_list.append('U')
print(combined_list)
# Out:
# ['K', 'H', 'U']

# %%
height=float(input())
weight=float(input())
height*=height
weight/=height
print('BMI:',weight)
print('體位:')
if weight<18.5:
  print('過輕')
elif 18.5<=weight<24:
  print('適中')
elif 24<=weight<27:
  print('過重')
else :
  print('肥胖')
# Out:
# 1.6
# 60
# BMI: 23.437499999999996
# 體位:
# 適中
